# %%
import pandas as pd
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[22,23,24]
df['City']=['Chennai','Pune','Hyderabad']

# %% [markdown]
# **step10: replace**

# %%
df
# Out:
#      Names  Age       City
# 0   Ramesh   22    Chennai
# 1   Suresh   23       Pune
# 2  Sathish   24  Hyderabad

# %%
df.replace('Ramesh','Prashanti') #inplace do not happen then it will not overwrite
# Out:
#        Names  Age       City
# 0  Prashanti   22    Chennai
# 1     Suresh   23       Pune
# 2    Sathish   24  Hyderabad

# %%
df
# Out:
#      Names  Age       City
# 0   Ramesh   22    Chennai
# 1   Suresh   23       Pune
# 2  Sathish   24  Hyderabad

# %%
import pandas as pd
df=pd.DataFrame()
df['Names']=['Ramesh','Suresh','Sathish']
df['Age']=[22,23,24]
df['City']=['Hyderabad','Pune','Hyderabad']
df["marks"]=[12,14,16]

# %%
df
# Out:
#      Names  Age       City  marks
# 0   Ramesh   22  Hyderabad     12
# 1   Suresh   23       Pune     14
# 2  Sathish   24  Hyderabad     16

# %%
df.replace(12,45)
# Out:
#      Names  Age       City  marks
# 0   Ramesh   22  Hyderabad     45
# 1   Suresh   23       Pune     14
# 2  Sathish   24  Hyderabad     16

# %%
df["marks"].replace(22,24,inplace=True)

# %%
df
# Out:
#      Names  Age       City  marks
# 0   Ramesh   22  Hyderabad     12
# 1   Suresh   23       Pune     14
# 2  Sathish   24  Hyderabad     16

# %%
#i want to change city name to chennai
# for those candidate who have age=24

# %% [markdown]
# **step11-np.where**

# %%
import numpy as np

# %% [raw]
# np.where(condition,True,False)
# age==24
# chennai
# Nochange

# %%
#I need to apply conditionn on age column
# we need to select a column
con=df["Age"]==24

# %%
con=df["Age"]==24
true="Chennai"
false=df["City"]

# %%
df['City']=np.where(con,true,false)

# %%
df
# Out:
#      Names  Age       City  marks
# 0   Ramesh   22  Hyderabad     12
# 1   Suresh   23       Pune     14
# 2  Sathish   24    Chennai     16

# %%
df
# Out:
#      Names  Age       City  marks
# 0   Ramesh   22  Hyderabad     12
# 1   Suresh   23       Pune     14
# 2  Sathish   24    Chennai     16

# %% [markdown]
# **loc-iloc**

# %%
df.loc[rows,columns]
 rows are like index numbers similar list slicing
l[start:stop:step]
columns are names any column name we can provide
df.iloc[rows,columns]
rows and columns are index number similar to list slice
l[start:stop:step]

# %%
rows=[1,2]
cols=['Age','City']
df.loc[rows,cols]
# Out:
#    Age       City
# 1   23       Pune
# 2   24  Hyderabad

# %%
cols=['Age','City']
df.loc[1:3,cols]
# Out:
#    Age     City
# 1   23     Pune
# 2   24  Chennai

# %%
df.loc[2]=['Anish',34,'bhopal',88]

# %%
df
# Out:
#     Names  Age       City  marks
# 0  Ramesh   22  Hyderabad     12
# 1  Suresh   23       Pune     14
# 2   Anish   34     bhopal     88

# %%
rows=[0,1]
cols=[2,3]
df.iloc[rows,cols]
# Out:
#         City  marks
# 0  Hyderabad     12
# 1       Pune     14

# %% [markdown]
# **step-13:how to save the dataframe**

# %%
#directory:where is the file available
#name:what is the name if file
#exteension: what is the type of file

###############################################
        #python location
#name:what is the name of file
#extension:what is the type of file

#dataframe variable=df
#name:student
#extensioon:.csv and .xlsv

df.to_csv('student.csv')

# %%
pd.read_csv('student.csv')
# Out:
#    Unnamed: 0   Names  Age       City  marks
# 0           0  Ramesh   22  Hyderabad     12
# 1           1  Suresh   23       Pune     14
# 2           2   Anish   34     bhopal     88

# %%
df.read_xlsv('student.xlsv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6132\1996569498.py in ?()
# ----> 1 df.read_xlsv('student.xlsv')
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'read_xlsv'

# %%
df.to_excel('student.xlsx')

# %%
pd.read_excel('student.xlsx')
# Out:
#    Unnamed: 0   Names  Age       City  marks
# 0           0  Ramesh   22  Hyderabad     12
# 1           1  Suresh   23       Pune     14
# 2           2   Anish   34     bhopal     88

# %%
#take a new notebook
#in your datafiles
#visadataset
#bankdataset pls load
#visadataset and all type of dataset

# %%
import pandas as pd

# %%
pd.read_csv(r"C:\Users\Prachi Choudhary\Downloads\Visadataset.csv")
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
