# %% [markdown]
# step1:import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **srep2: create a dataframe using list**

# %%
Names=["Ramesh","Suresh","Satish"]
#pd.Dataframe(data,index,columns)
pd.DataFrame(Names)
# Out:
#         0
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %% [markdown]
# **step3:name the column**

# %%
Names=["Ramesh","Suresh","Satish"]
#pd.DataFrame(data,index,columns)
pd.DataFrame(Names,columns=['Names'])
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Satish

# %% [markdown]
# **step4:chnage the index**

# %%
Names=["Ramesh","Suresh","Satish"]
pd.DataFrame(Names,index=["A","B","C"],columns=['Names'])
# Out:
#     Names
# A  Ramesh
# B  Suresh
# C  Satish

# %% [markdown]
# **step5:two columns**

# %%
Names=["Ramesh","Suresh","Satish"]
Age=[20,22,24]
data=zip(Names,Age)
cols=["Names","Age"]
pd.DataFrame(data,columns=cols)
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Satish   24

# %% [markdown]
# **step6:add data to empty dataframe**

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame()
df["Names"]=["Ramesh","Suresh","Satish"]
df["Age"]=[20,22,24]
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=pd.DataFrame()
#       2 df["Names"]=["Ramesh","Suresh","Satish"]
#       3 df["Age"]=[20,22,24]
#
# NameError: name 'pd' is not defined

# %% [markdown]
# **Error**
# - key error=columns not equal
# - dimension error=column length is mismatched

# %%
df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Satish   24

# %%
#already data frame is available then add a column to existing dataframe
df["City"]=["Chennai","Pune","Mumbai"]
df
# Out:
#     Names  Age     City
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %% [markdown]
# **Methods**

# %% [markdown]
# **step8:rename the column**

# %%
# i want the rename from capital city to small city
#df.rename(mapper,index,columns,axis,inplace)
d={'City':'city'}
df.rename(columns=d)
# Out:
#     Names  Age     city
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
d={'City':'city'}
df.rename(d)
df.rename(axis=0)#index
df.rename(axis=1)#column
df.rename(index=d)#index
df.rename(columns=d)#columns
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3976\3084580105.py in ?()
# ----> 1 df.rename(d,index=0,inplace=True)
#       2 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    5785         0  1  4
#    5786         2  2  5
#    5787         4  3  6
#    5788         """
# -> 5789         return super()._rename(
#    5790             mapper=mapper,
#    5791             index=index,
#    5792             columns=columns,
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, mapper, index, columns, axis, copy, inplace, level, errors)
#    1093                 raise TypeError(
#    1094                     "Cannot specify both 'axis' and any of 'index' or 'columns'"
#    1095                 )
#    1096             if mapper is not None:
# ...

# %%
d={'City':'city'}
df.rename(columns=d)
# Out:
#     Names  Age     city
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
d={'City':'city'}
df.rename(d)
# Out:
#     Names  Age     City
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
d={'City':'city'}
df.rename(index=d)
# Out:
#     Names  Age     City
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
d={'City':'city'}
df.rename(d,axis=0)
# Out:
#     Names  Age     City
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
d={'City':'city'}
df.rename(d,axis=1)
# Out:
#     Names  Age     city
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
df.columns=["names","age","city"]

# %%
df
# Out:
#     names  age     city
# 0  Ramesh   20  Chennai
# 1  Suresh   22     Pune
# 2  Satish   24   Mumbai

# %%
df.index=["s","q","p"]

# %%
df
# Out:
#     names  age     city
# s  Ramesh   20  Chennai
# q  Suresh   22     Pune
# p  Satish   24   Mumbai

# %% [markdown]
# **#step9:drop the columns**

# %%
#I want to drop"city columns"
df.drop('City')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 #I want to drop"city columns"
# ----> 2 df.drop('City')
#
# NameError: name 'df' is not defined

# %%
df.drop('age',axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.drop('age',axis=1)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#     names  age     city
# s  Ramesh   20  Chennai
# q  Suresh   22     Pune
# p  Satish   24   Mumbai

# %%
d={'City':'city'}
df.rename(d,axis=1)
df.drop('c')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 d={'City':'city'}
# ----> 2 df.rename(d,axis=1)
#       3 df.drop('c')
#
# NameError: name 'df' is not defined

# %%
Names=["Ramesh","Sures",""]
city=
age=[]
data=zip()
df=pd.datafrme
